# %%
#Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

#Criando um DataFrame simples
data = {
    "Ano": [2020,2021,2022,2023,2024],
    "Venda": [1220,1452,1357,1157,4954]
}

df = pd.DataFrame(data)

#Exibindo o DataFrame
print(df)

#Criando um gráfico simples
plt.plot(df["Ano"], df["Venda"], marker="o")
plt.title("Vendas Anuais")
plt.xlabel("Ano")
plt.ylabel("Vendas")
plt.grid(True)
plt.show()
# Out:
#     Ano  Venda
# 0  2020   1220
# 1  2021   1452
# 2  2022   1357
# 3  2023   1157
# 4  2024   4954
